# %%
import pandas as pd

# %%
import requests

# %% [markdown]
# load the df from session 3

# %%
df = pd.read_pickle("../session3/savedDF.pickle")

# %%
df.head()
# Out:
#   Country (according to CN Gov): Date of research inquiry  \
# 1                    Afghanistan                      NaT
# 2                        Albania                      NaT
# 3                        Armenia                      NaT
# 4                     Azerbaijan                      NaT
# 5                        Bahrain                      NaT
#
#    HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
#
#    Heritage Foundation Index of Economic Freedom (Global Ranking)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Bertelsmann Transformation index (BTI)  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
#
#    Bertelsmann Transformation index (BTI) - Ranking  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
#
#   IMF WB\nCustoms and other import duties (% of tax revenue) 2016  \
# 1                                            35.2031
# 2                                            2.21646
# 3                                            6.27539
# 4                                            7.57185
# 5                                            27.3861
#
#   WB IMF Non-performing loans to total gross loans ratio (%)  \
# 1                                            12.2018
# 2                                            13.2325
# 3                                            5.43232
# 4                                                 NA
# 5                                                 NA
#
#   Moody's Socvereign Ratings List S&P Sovereign Ratings List  ...  \
# 1                             NaN                        NaN  ...
# 2                             NaN                        NaN  ...
# 3                             NaN                        NaN  ...
# 4                             NaN                        NaN  ...
# 5                             NaN                        NaN  ...
#
#   WB Cost of Starting a Business  \
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
#
#   WB Ease of Doing Business Index (1 = most business-friendly regulations)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   WB Logistics Performance Index (LPI) (range: 1-5)   \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   IFDI Net Inflows (% of GDP) ED National Electric Power Consumption TwH  \
# 1                    0.718898                                        NaN
# 2                     8.01551                                        NaN
# 3                     2.04411                                        NaN
# 4                     2.98895                                        NaN
# 5                     4.01407                                        NaN
#
#   WHO Current Health Expenditure p.c., PPP USD  \
# 1                                      162.781
# 2                                      759.667
# 3                                      876.857
# 4                                      1193.06
# 5                                       1866.3
#
#    WB Research Expenditure % of GDP  WIPO Trademark applications  \
# 1                                NA                           NA
# 2                           0.15412                         1232
# 3                            0.2277                         2685
# 4                           0.18521                         2817
# 5                           0.10116                          253
#
#    WIPO Patent Applications  isocode
# 1                        NA      AFG
# 2                        14      ALB
# 3                       107      ARM
# 4                       144      AZE
# 5                         8      BHR
#
# [5 rows x 44 columns]

# %% [markdown]
# 1. BTI

# %%
bti_df = pd.read_csv('data-BTI-2006-2018.csv')

# %%
bti_df.head()
# Out:
#        country country_code  year            region  rank_stat_ind  stat_ind  \
# 0  Afghanistan          AFG  2006  Asia and Oceania            112  3.019048
# 1  Afghanistan          AFG  2008  Asia and Oceania            120  3.136905
# 2  Afghanistan          AFG  2010  Asia and Oceania            124  2.810714
# 3  Afghanistan          AFG  2012  Asia and Oceania            124  2.821429
# 4  Afghanistan          AFG  2014  Asia and Oceania            122  2.965476
#
#    rank_dem_stat  dem_stat  stateness  monopoly  ...  stab_econ_cat  \
# 0            109  2.966667       3.00         2  ...           Fair
# 1            108  3.416667       3.25         2  ...           Fair
# 2            123  2.800000       2.75         1  ...           Fair
# 3            124  2.750000       3.25         2  ...           Fair
# 4            120  2.966667       3.50         3  ...           Fair
#
#    priv_prop_cat  welfare_cat  perf_econ_cat  sustain_cat  level_diff_cat  \
# 0           Fair         Poor         Flawed         Poor       Excellent
# 1         Flawed         Poor           Fair         Poor       Excellent
# 2         Flawed         Poor           Fair         Poor       Excellent
# 3         Flawed         Poor           Fair         Poor       Excellent
# 4         Flawed         Poor           Fair         Poor       Excellent
#
#    steering_cat  efficiency_cat  consens_cat  int_coop_cat
# 0        Flawed            Poor       Flawed         Sound
# 1        Flawed            Poor       Flawed         Sound
# 2        Flawed            Poor       Flawed          Fair
# 3        Flawed            Poor       Flawed          Fair
# 4        Flawed            Poor       Flawed          Fair
#
# [5 rows x 113 columns]

# %% [markdown]
# All the lines where the year is 2018

# %%
bti_latestYear = bti_df[bti_df['year'] == 2018]

# %%
bti_latestYear.head()
# Out:
#         country country_code  year                             region  \
# 6   Afghanistan          AFG  2018                   Asia and Oceania
# 13      Albania          ALB  2018  East-Central and Southeast Europe
# 20      Algeria          DZA  2018       Middle East and North Africa
# 27       Angola          AGO  2018              South and East Africa
# 34    Argentina          ARG  2018    Latin America and the Caribbean
#
#     rank_stat_ind  stat_ind  rank_dem_stat  dem_stat  stateness  monopoly  \
# 6             121  2.954762            114  3.016667       3.75         2
# 13             30  6.828571             34  7.050000       9.00        10
# 20             83  4.982143             79  4.750000       7.50         8
# 27            105  3.939286             87  4.200000       7.50         8
# 34             23  7.267857             19  8.000000       9.00         8
#
#     ...  stab_econ_cat  priv_prop_cat  welfare_cat  perf_econ_cat  \
# 6   ...         Flawed         Flawed       Flawed         Flawed
# 13  ...          Sound          Sound        Sound           Fair
# 20  ...          Sound           Fair         Fair           Fair
# 27  ...           Fair         Flawed       Flawed         Flawed
# 34  ...          Sound          Sound        Sound           Fair
#
#     sustain_cat  level_diff_cat  steering_cat  efficiency_cat  consens_cat  \
# 6        Flawed       Excellent        Flawed          Flawed       Flawed
# 13         Fair          Flawed         Sound            Fair        Sound
# 20         Fair            Fair          Fair            Fair         Fair
# 27       Flawed            Fair        Flawed          Flawed       Flawed
# 34         Fair          Flawed         Sound            Fair        Sound
#
#     int_coop_cat
# 6           Fair
# 13         Sound
# 20          Fair
# 27          Fair
# 34         Sound
#
# [5 rows x 113 columns]

# %% [markdown]
# Select the data we need for the latest year

# %%
bti_rank = bti_latestYear.rank_stat_ind

# %%
for index, isocode in df.isocode.iteritems():
    try:
        indicator = bti_latestYear[bti_latestYear['country_code']==isocode]['stat_ind']
        rank = bti_latestYear[bti_latestYear['country_code']==isocode]['rank_stat_ind']
        # at the row bti_latestYear[bti_latestYear['country code'] == isocode] and the column for 'Bertelsmann...' put indicator : 
        df.at[index, 'Bertelsmann Transformation index (BTI)'] = indicator
        df.at[index, 'Bertelsmann Transformation index (BTI) - Ranking'] = rank
    except ValueError:
        print('[critical]: no data for', isocode)
        continue
# Out:
# [critical]: no data for BRN
# [critical]: no data for TLS
# [critical]: no data for FRA
# [critical]: no data for DEU
# [critical]: no data for IOT
# [critical]: no data for ISR
# [critical]: no data for MDV
# [critical]: no data for ROU
# [critical]: no data for GBR
# [critical]: no data for USA

# %%
df[['Country (according to CN Gov):', 'Bertelsmann Transformation index (BTI)', 'Bertelsmann Transformation index (BTI) - Ranking']].head()
# Out:
#   Country (according to CN Gov):  Bertelsmann Transformation index (BTI)  \
# 1                    Afghanistan                                2.954762
# 2                        Albania                                6.828571
# 3                        Armenia                                5.576190
# 4                     Azerbaijan                                4.127381
# 5                        Bahrain                                4.616667
#
#    Bertelsmann Transformation index (BTI) - Ranking
# 1                                             121.0
# 2                                              30.0
# 3                                              61.0
# 4                                             100.0
# 5                                              89.0

# %% [markdown]
# 2. CPI

# %%
cpi_df = pd.read_excel('data-CPI-2018.xlsx')

# %%
cpi_df.head()
# Out:
#   Corruption Perceptions Index 2018: Global Scores  Unnamed: 1 Unnamed: 2  \
# 0                                               NaN        NaN        NaN
# 1                                           Country       ISO3     Region
# 2                                           Denmark        DNK      WE/EU
# 3                                       New Zealand        NZL         AP
# 4                                           Finland        FIN      WE/EU
#
#        Unnamed: 3 Unnamed: 4      Unnamed: 5         Unnamed: 6 Unnamed: 7  \
# 0             NaN        NaN             NaN                NaN        NaN
# 1  CPI Score 2018      Rank   Standard error  Number of sources   Upper CI
# 2              88          1            2.63                  8         92
# 3              87          2            2.44                  8         91
# 4              85          3            2.74                  8         89
#
#   Unnamed: 8                     Unnamed: 9  ...  \
# 0        NaN                            NaN  ...
# 1  Lower CI   African Development Bank CPIA  ...
# 2         84                            NaN  ...
# 3         83                            NaN  ...
# 4         81                            NaN  ...
#
#                                    Unnamed: 12  \
# 0                                          NaN
# 1  Economist Intelligence Unit Country Ratings
# 2                                           90
# 3                                           90
# 4                                           72
#
#                                 Unnamed: 13  \
# 0                                       NaN
# 1  Freedom House Nations in Transit Ratings
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                            Unnamed: 14                         Unnamed: 15  \
# 0                                  NaN                                 NaN
# 1  Global Insight Country Risk Ratings  IMD World Competitiveness Yearbook
# 2                                   83                                  97
# 3                                   83                                  92
# 4                                   83                                  93
#
#             Unnamed: 16                           Unnamed: 17  \
# 0                   NaN                                   NaN
# 1  PERC Asia Risk Guide  PRS International Country Risk Guide
# 2                   NaN                                    92
# 3                   NaN                                    93
# 4                   NaN                                    93
#
#        Unnamed: 18               Unnamed: 19  \
# 0              NaN                       NaN
# 1  World Bank CPIA  World Economic Forum EOS
# 2              NaN                        79
# 3              NaN                        83
# 4              NaN                        90
#
#                                Unnamed: 20                     Unnamed: 21
# 0                                      NaN                             NaN
# 1  World Justice Project Rule of Law Index  Varieties of Democracy Project
# 2                                       88                              78
# 3                                       82                              77
# 4                                       86                              76
#
# [5 rows x 22 columns]

# %%
cpi_df = pd.read_excel('data-CPI-2018.xlsx', header=2)
cpi_df.head()
# Out:
#        Country ISO3 Region  CPI Score 2018  Rank   Standard error  \
# 0      Denmark  DNK  WE/EU              88      1            2.63
# 1  New Zealand  NZL     AP              87      2            2.44
# 2      Finland  FIN  WE/EU              85      3            2.74
# 3    Singapore  SGP     AP              85      3            1.98
# 4       Sweden  SWE  WE/EU              85      3            2.02
#
#    Number of sources  Upper CI  Lower CI   African Development Bank CPIA  ...  \
# 0                  8        92         84                            NaN  ...
# 1                  8        91         83                            NaN  ...
# 2                  8        89         81                            NaN  ...
# 3                  9        88         82                            NaN  ...
# 4                  8        88         82                            NaN  ...
#
#    Economist Intelligence Unit Country Ratings  \
# 0                                         90.0
# 1                                         90.0
# 2                                         72.0
# 3                                         90.0
# 4                                         90.0
#
#    Freedom House Nations in Transit Ratings  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    Global Insight Country Risk Ratings  IMD World Competitiveness Yearbook  \
# 0                                   83                                97.0
# 1                                   83                                92.0
# 2                                   83                                93.0
# 3                                   83                                90.0
# 4                                   83                                81.0
#
#    PERC Asia Risk Guide  PRS International Country Risk Guide  \
# 0                   NaN                                  92.0
# 1                   NaN                                  93.0
# 2                   NaN                                  93.0
# 3                  89.0                                  85.0
# 4                   NaN                                  93.0
#
#    World Bank CPIA  World Economic Forum EOS  \
# 0              NaN                      79.0
# 1              NaN                      83.0
# 2              NaN                      90.0
# 3              NaN                      90.0
# 4              NaN                      77.0
#
#    World Justice Project Rule of Law Index  Varieties of Democracy Project
# 0                                     88.0                            78.0
# 1                                     82.0                            77.0
# 2                                     86.0                            76.0
# 3                                     85.0                            78.0
# 4                                     86.0                            78.0
#
# [5 rows x 22 columns]

# %% [markdown]
# To see the space for Rank:

# %%
cpi_df.columns
# Out:
# Index(['Country', 'ISO3', 'Region', 'CPI Score 2018', 'Rank ',
#        'Standard error', 'Number of sources', 'Upper CI', 'Lower CI ',
#        'African Development Bank CPIA',
#        'Bertelsmann Foundation Sustainable Governance Index',
#        'Bertelsmann Foundation Transformation Index',
#        'Economist Intelligence Unit Country Ratings',
#        'Freedom House Nations in Transit Ratings',
#        'Global Insight Country Risk Ratings',
#        'IMD World Competitiveness Yearbook', 'PERC Asia Risk Guide',
#        'PRS International Country Risk Guide', 'World Bank CPIA',
#        'World Economic Forum EOS', 'World Justice Project Rule of Law Index',
#        'Varieties of Democracy Project'],
#       dtype='object')

# %%
for index, isocode in df.isocode.iteritems():
    try:
        indicator = cpi_df[cpi_df['ISO3']==isocode]['CPI Score 2018']
        rank = cpi_df[cpi_df['ISO3']==isocode]['Rank ']
        df.at[index, 'TI Corruption Perception Index'] = indicator
        df.at[index, 'TI Corruption Perception Index - Ranking'] = rank
    except ValueError:
        print('[critical]: no data for', isocode)
        continue
# Out:
# [critical]: no data for IOT

# %%
df[['TI Corruption Perception Index', 'TI Corruption Perception Index - Ranking']]
# Out:
#     TI Corruption Perception Index  TI Corruption Perception Index - Ranking
# 1                             16.0                                     172.0
# 2                             36.0                                      99.0
# 3                             35.0                                     105.0
# 4                             25.0                                     152.0
# 5                             36.0                                      99.0
# 6                             26.0                                     149.0
# 7                             44.0                                      70.0
# 8                             68.0                                      25.0
# 9                             38.0                                      89.0
# 10                            63.0                                      31.0
# 11                            42.0                                      77.0
# 12                            20.0                                     161.0
# 13                            39.0                                      87.0
# 14                            48.0                                      60.0
# 15                            59.0                                      38.0
# 16                            35.0                                     105.0
# 17                            35.0                                     105.0
# 18                            73.0                                      18.0
# 19                            72.0                                      21.0
# 20                            58.0                                      41.0
# 21                            80.0                                      11.0
# 22                            46.0                                      64.0
# 23                             NaN                                       NaN
# 24                            38.0                                      89.0
# 25                            28.0                                     138.0
# 26                            18.0                                     168.0
# 27                            61.0                                      34.0
# 28                            49.0                                      58.0
# 29                            31.0                                     124.0
# 30                            41.0                                      78.0
# ..                             ...                                       ...
# 39                            33.0                                     117.0
# 40                            37.0                                      93.0
# 41                            45.0                                      67.0
# 42                            29.0                                     132.0
# 43                            31.0                                     124.0
# 44                            52.0                                      53.0
# 45                            33.0                                     117.0
# 46                            36.0                                      99.0
# 47                            60.0                                      36.0
# 48                            62.0                                      33.0
# 49                            47.0                                      61.0
# 50                            28.0                                     138.0
# 51                            49.0                                      58.0
# 52                            39.0                                      87.0
# 53                            85.0                                       3.0
# 54                            50.0                                      57.0
# 55                            60.0                                      36.0
# 56                            38.0                                      89.0
# 57                            13.0                                     178.0
# 58                            25.0                                     152.0
# 59                            36.0                                      99.0
# 60                            70.0                                      23.0
# 61                            41.0                                      78.0
# 62                            20.0                                     161.0
# 63                            80.0                                      11.0
# 64                            71.0                                      22.0
# 65                            32.0                                     120.0
# 66                            23.0                                     158.0
# 67                            33.0                                     117.0
# 68                            14.0                                     176.0
#
# [68 rows x 2 columns]

# %% [markdown]
# 3. Heritage

# %% [markdown]
# Get isocode from clean country name

# %%
heritage_df = pd.read_excel('data-heritage-2019.xls')
heritage_df.head()
# Out:
#    CountryID Country Name      WEBNAME                        Region  \
# 0          1  Afghanistan  Afghanistan                  Asia-Pacific
# 1          2      Albania      Albania                        Europe
# 2          3      Algeria      Algeria  Middle East and North Africa
# 3          4       Angola       Angola            Sub-Saharan Africa
# 4          5    Argentina    Argentina                      Americas
#
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# 4       148.0         26.0        52.2             47.8
#
#    Judical Effectiveness  Government Integrity  ...      Country  \
# 0                   29.6                  25.2  ...  Afghanistan
# 1                   30.6                  40.4  ...      Albania
# 2                   36.2                  28.9  ...      Algeria
# 3                   26.6                  20.5  ...       Angola
# 4                   44.5                  33.5  ...    Argentina
#
#    Population (Millions)  GDP (Billions, PPP)  GDP Growth Rate (%)  \
# 0                   35.5                 69.6                2.505
# 1                    2.9                   36                3.900
# 2                   41.5                632.9                2.000
# 3                   28.2                190.3                0.700
# 4                   44.1                920.2                2.900
#
#    5 Year GDP Growth Rate (%)  GDP per Capita (PPP)  Unemployment (%)  \
# 0                         2.9               1957.58               8.8
# 1                         2.5               12506.6              13.9
# 2                         3.1               15237.2                10
# 3                         2.9               6752.58               8.2
# 4                         0.7               20875.8               8.7
#
#    Inflation (%)  FDI Inflow (Millions)  Public Debt (% of GDP)
# 0            5.0                   53.9                     7.3
# 1            2.0                 1119.1                    71.2
# 2            5.6                 1203.0                    25.8
# 3           31.7                -2254.5                    65.3
# 4           25.7                11857.0                    52.6
#
# [5 rows x 34 columns]

# %%
for index, name in df['Country (according to CN Gov):'].items():          
    cleanedName = name.split(' (')[0].strip()
    if cleanedName == "Thailiand":
        cleanedName = "Thailand"
    elif cleanedName == "The United Arab Emirates":
        cleanedName = "United Arab Emirates"
    elif cleanedName == "Brunei":
        cleanedName = "Brunei Darussalam"
    elif cleanedName == "Myanmar":
        cleanedName = "Burma"
    elif cleanedName == "East Timor":
        cleanedName = "Timor-Leste"
    elif cleanedName == "Kyrgyzstan":
        cleanedName = "Kyrgyz Republic"
    elif cleanedName == "United States of America":
        cleanedName = "United States"
    try:
        indicator = heritage_df[heritage_df['Country Name']==cleanedName]['2019 Score']
        indicator = heritage_df[heritage_df['Country Name']==cleanedName]['World Rank']
        df.at[index, 'HF Index of Economic Freedom (Scale: 1-100)'] = indicator
        df.at[index, 'Heritage Foundation Index of Economic Freedom (Global Ranking)'] = rank
    except ValueError:
        print('[critical]: no data for', cleanedName)
        continue

# %%
df[['HF Index of Economic Freedom (Scale: 1-100)', 'Heritage Foundation Index of Economic Freedom (Global Ranking)']].head()
# Out:
#    HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                        152.0
# 2                                         52.0
# 3                                         47.0
# 4                                         60.0
# 5                                         54.0
#
#    Heritage Foundation Index of Economic Freedom (Global Ranking)
# 1                                              176.0
# 2                                              176.0
# 3                                              176.0
# 4                                              176.0
# 5                                              176.0

# %%
df.head()
# Out:
#   Country (according to CN Gov): Date of research inquiry  \
# 1                    Afghanistan                      NaT
# 2                        Albania                      NaT
# 3                        Armenia                      NaT
# 4                     Azerbaijan                      NaT
# 5                        Bahrain                      NaT
#
#    HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                        152.0
# 2                                         52.0
# 3                                         47.0
# 4                                         60.0
# 5                                         54.0
#
#    Heritage Foundation Index of Economic Freedom (Global Ranking)  \
# 1                                              176.0
# 2                                              176.0
# 3                                              176.0
# 4                                              176.0
# 5                                              176.0
#
#    Bertelsmann Transformation index (BTI)  \
# 1                                2.954762
# 2                                6.828571
# 3                                5.576190
# 4                                4.127381
# 5                                4.616667
#
#    Bertelsmann Transformation index (BTI) - Ranking  \
# 1                                             121.0
# 2                                              30.0
# 3                                              61.0
# 4                                             100.0
# 5                                              89.0
#
#   IMF WB\nCustoms and other import duties (% of tax revenue) 2016  \
# 1                                            35.2031
# 2                                            2.21646
# 3                                            6.27539
# 4                                            7.57185
# 5                                            27.3861
#
#   WB IMF Non-performing loans to total gross loans ratio (%)  \
# 1                                            12.2018
# 2                                            13.2325
# 3                                            5.43232
# 4                                                 NA
# 5                                                 NA
#
#   Moody's Socvereign Ratings List S&P Sovereign Ratings List  ...  \
# 1                             NaN                        NaN  ...
# 2                             NaN                        NaN  ...
# 3                             NaN                        NaN  ...
# 4                             NaN                        NaN  ...
# 5                             NaN                        NaN  ...
#
#   WB Cost of Starting a Business  \
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
#
#   WB Ease of Doing Business Index (1 = most business-friendly regulations)  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   WB Logistics Performance Index (LPI) (range: 1-5)   \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#   IFDI Net Inflows (% of GDP) ED National Electric Power Consumption TwH  \
# 1                    0.718898                                        NaN
# 2                     8.01551                                        NaN
# 3                     2.04411                                        NaN
# 4                     2.98895                                        NaN
# 5                     4.01407                                        NaN
#
#   WHO Current Health Expenditure p.c., PPP USD  \
# 1                                      162.781
# 2                                      759.667
# 3                                      876.857
# 4                                      1193.06
# 5                                       1866.3
#
#    WB Research Expenditure % of GDP  WIPO Trademark applications  \
# 1                                NA                           NA
# 2                           0.15412                         1232
# 3                            0.2277                         2685
# 4                           0.18521                         2817
# 5                           0.10116                          253
#
#    WIPO Patent Applications  isocode
# 1                        NA      AFG
# 2                        14      ALB
# 3                       107      ARM
# 4                       144      AZE
# 5                         8      BHR
#
# [5 rows x 44 columns]

# %% [markdown]
# 4. Moody's

# %% [markdown]
# We need ISO2 for moody's

# %%
iso2 = {}

# %%
for index, name in df['Country (according to CN Gov):'].items():    
    if name in iso2:
        continue        
    cleanedName = name.split(' (')[0].strip()
    if cleanedName == "Thailiand":
        cleanedName = "Thailand"
    if cleanedName == "The United Arab Emirates":
        cleanedName = "United Arab Emirates"
    url = 'http://www.restcountries.eu/rest/v2/name/'+cleanedName
    r = requests.get(url)
    if r.status_code == 200:
        data = r.json()
        country_code = data[0]['alpha2Code']
        iso2[name] = country_code
    else:
        print('[ERROR]['+ name +'] we cannot get the data, reason is ', r.status_code, r.text)

# %%
ratings_df = pd.read_csv('data-ratings-2015.csv', delimiter=";")
ratings_df.head()
# Out:
#   Country2Code  Year  SP_NumericRating  Moodys_NumericRating  \
# 0           DO  2001               9.0                  10.0
# 1           DO  2002               9.0                  10.0
# 2           DO  2003               4.0                   7.0
# 3           DO  2004               2.0                   6.0
# 4           DO  2005               7.0                   6.0
#
#    Fitch_NumericRating  Diff_UP_SM  Diff_DW_SM  Diff_UP_MF  Diff_DW_MF  \
# 0                  NaN         NaN         1.0         NaN         NaN
# 1                  NaN         NaN         1.0         NaN         NaN
# 2                  7.0         NaN         3.0         0.0         0.0
# 3                  5.0         NaN         4.0         1.0         NaN
# 4                  6.0         1.0         NaN         0.0         0.0
#
#    Diff_UP_SF  ...  NGDP_RPCH  ExtDebtPercGNI  GGXWDG_NGDP  GGXWDN_NGDP  \
# 0         NaN  ...      1.791           22.06       15.581       15.581
# 1         NaN  ...      5.776           26.10       16.536       16.536
# 2         NaN  ...     -0.252           36.60       34.108       34.108
# 3         NaN  ...      1.304           38.66       22.500       22.500
# 4         1.0  ...      9.222           24.15       21.290       21.290
#
#    GGSB_NPGDP  DefaultLastYear  DefaultLast2Years  DefaultLast5Years  \
# 0      -1.456                1                  1                  1
# 1      -1.901                1                  1                  1
# 2      -4.657                1                  1                  1
# 3      -2.696                1                  1                  1
# 4      -0.440                1                  1                  1
#
#    DefaultLast10Years  PCPIPCH
# 0                   1    8.884
# 1                   1    5.223
# 2                   1   27.450
# 3                   1   51.461
# 4                   1    4.190
#
# [5 rows x 22 columns]

# %%
ratings2015 = ratings_df[ratings_df['Year']==2015]
ratings_df[ratings_df['Year']==2015].head()
# Out:
#    Country2Code  Year  SP_NumericRating  Moodys_NumericRating  \
# 14           DO  2015               9.0                   8.0
# 31           MA  2015              12.0                  11.0
# 32           AO  2015               8.0                  10.0
# 38           AL  2015               7.0                   8.0
# 47           AE  2015              19.0                  19.0
#
#     Fitch_NumericRating  Diff_UP_SM  Diff_DW_SM  Diff_UP_MF  Diff_DW_MF  \
# 14                  8.0         1.0         NaN         0.0         0.0
# 31                 12.0         1.0         NaN         NaN         1.0
# 32                  8.0         NaN         2.0         2.0         NaN
# 38                  NaN         NaN         1.0         NaN         NaN
# 47                 19.0         0.0         0.0         0.0         0.0
#
#     Diff_UP_SF  ...  NGDP_RPCH  ExtDebtPercGNI  GGXWDG_NGDP  GGXWDN_NGDP  \
# 14         1.0  ...      7.000             0.0       34.289       34.289
# 31         0.0  ...      4.466             0.0       63.165       63.667
# 32         0.0  ...      2.998             0.0        0.000       62.325
# 38         NaN  ...      2.639             0.0       71.886       71.886
# 47         0.0  ...      3.930             0.0     -258.810       19.419
#
#     GGSB_NPGDP  DefaultLastYear  DefaultLast2Years  DefaultLast5Years  \
# 14      -2.707                1                  1                  1
# 31      -4.943                0                  0                  1
# 32       0.000                1                  1                  1
# 38       0.000                0                  1                  1
# 47       0.000                0                  0                  0
#
#     DefaultLast10Years  PCPIPCH
# 14                   1    0.837
# 31                   1    1.600
# 32                   1   10.275
# 38                   1    1.896
# 47                   0    4.068
#
# [5 rows x 22 columns]

# %%
for index, isocode in df.isocode.iteritems():
    try:
        sp = ratings2015[ratings2015['Country2Code']==iso2]['SP_NumericRating']
        moody = ratings2015[ratings2015['Country2Code']==iso2]['Moodys_NumericRating']
        fitch = ratings2015[ratings2015['Country2Code']==iso2]['Fitch_NumericRating']
        df.at[index, 'S&P Sovereign Ratings List'] = sp
        df.at[index, "Moody's Socvereign Ratings List"] = moody
        df.at[index, 'Fitch Sovereign Ratings List'] = fitch
    except ValueError:
        print('[critical]: no data for', isocode)
        continue

# %%
df[["S&P Sovereign Ratings List", "Moody's Socvereign Ratings List", "Fitch Sovereign Ratings List"]]
# Out:
#                            S&P Sovereign Ratings List  \
# 1   Series([], Name: SP_NumericRating, dtype: floa...
# 2   Series([], Name: SP_NumericRating, dtype: floa...
# 3   Series([], Name: SP_NumericRating, dtype: floa...
# 4   Series([], Name: SP_NumericRating, dtype: floa...
# 5   Series([], Name: SP_NumericRating, dtype: floa...
# 6   Series([], Name: SP_NumericRating, dtype: floa...
# 7   Series([], Name: SP_NumericRating, dtype: floa...
# 8   Series([], Name: SP_NumericRating, dtype: floa...
# 9   Series([], Name: SP_NumericRating, dtype: floa...
# 10  Series([], Name: SP_NumericRating, dtype: floa...
# 11  Series([], Name: SP_NumericRating, dtype: floa...
# 12  Series([], Name: SP_NumericRating, dtype: floa...
# 13  Series([], Name: SP_NumericRating, dtype: floa...
# 14  Series([], Name: SP_NumericRating, dtype: floa...
# 15  Series([], Name: SP_NumericRating, dtype: floa...
# 16  Series([], Name: SP_NumericRating, dtype: floa...
# 17  Series([], Name: SP_NumericRating, dtype: floa...
# 18  Series([], Name: SP_NumericRating, dtype: floa...
# 19  Series([], Name: SP_NumericRating, dtype: floa...
# 20  Series([], Name: SP_NumericRating, dtype: floa...
# 21  Series([], Name: SP_NumericRating, dtype: floa...
# 22  Series([], Name: SP_NumericRating, dtype: floa...
# 23  Series([], Name: SP_NumericRating, dtype: floa...
# 24  Series([], Name: SP_NumericRating, dtype: floa...
# 25  Series([], Name: SP_NumericRating, dtype: floa...
# 26  Series([], Name: SP_NumericRating, dtype: floa...
# 27  Series([], Name: SP_NumericRating, dtype: floa...
# 28  Series([], Name: SP_NumericRating, dtype: floa...
# 29  Series([], Name: SP_NumericRating, dtype: floa...
# 30  Series([], Name: SP_NumericRating, dtype: floa...
# ..                                                ...
# 39  Series([], Name: SP_NumericRating, dtype: floa...
# 40  Series([], Name: SP_NumericRating, dtype: floa...
# 41  Series([], Name: SP_NumericRating, dtype: floa...
# 42  Series([], Name: SP_NumericRating, dtype: floa...
# 43  Series([], Name: SP_NumericRating, dtype: floa...
# 44  Series([], Name: SP_NumericRating, dtype: floa...
# 45  Series([], Name: SP_NumericRating, dtype: floa...
# 46  Series([], Name: SP_NumericRating, dtype: floa...
# 47  Series([], Name: SP_NumericRating, dtype: floa...
# 48  Series([], Name: SP_NumericRating, dtype: floa...
# 49  Series([], Name: SP_NumericRating, dtype: floa...
# 50  Series([], Name: SP_NumericRating, dtype: floa...
# 51  Series([], Name: SP_NumericRating, dtype: floa...
# 52  Series([], Name: SP_NumericRating, dtype: floa...
# 53  Series([], Name: SP_NumericRating, dtype: floa...
# 54  Series([], Name: SP_NumericRating, dtype: floa...
# 55  Series([], Name: SP_NumericRating, dtype: floa...
# 56  Series([], Name: SP_NumericRating, dtype: floa...
# 57  Series([], Name: SP_NumericRating, dtype: floa...
# 58  Series([], Name: SP_NumericRating, dtype: floa...
# 59  Series([], Name: SP_NumericRating, dtype: floa...
# 60  Series([], Name: SP_NumericRating, dtype: floa...
# 61  Series([], Name: SP_NumericRating, dtype: floa...
# 62  Series([], Name: SP_NumericRating, dtype: floa...
# 63  Series([], Name: SP_NumericRating, dtype: floa...
# 64  Series([], Name: SP_NumericRating, dtype: floa...
# 65  Series([], Name: SP_NumericRating, dtype: floa...
# 66  Series([], Name: SP_NumericRating, dtype: floa...
# 67  Series([], Name: SP_NumericRating, dtype: floa...
# 68  Series([], Name: SP_NumericRating, dtype: floa...
#
#                       Moody's Socvereign Ratings List  \
# 1   Series([], Name: Moodys_NumericRating, dtype: ...
# 2   Series([], Name: Moodys_NumericRating, dtype: ...
# 3   Series([], Name: Moodys_NumericRating, dtype: ...
# 4   Series([], Name: Moodys_NumericRating, dtype: ...
# 5   Series([], Name: Moodys_NumericRating, dtype: ...
# 6   Series([], Name: Moodys_NumericRating, dtype: ...
# 7   Series([], Name: Moodys_NumericRating, dtype: ...
# 8   Series([], Name: Moodys_NumericRating, dtype: ...
# 9   Series([], Name: Moodys_NumericRating, dtype: ...
# 10  Series([], Name: Moodys_NumericRating, dtype: ...
# 11  Series([], Name: Moodys_NumericRating, dtype: ...
# 12  Series([], Name: Moodys_NumericRating, dtype: ...
# 13  Series([], Name: Moodys_NumericRating, dtype: ...
# 14  Series([], Name: Moodys_NumericRating, dtype: ...
# 15  Series([], Name: Moodys_NumericRating, dtype: ...
# 16  Series([], Name: Moodys_NumericRating, dtype: ...
# 17  Series([], Name: Moodys_NumericRating, dtype: ...
# 18  Series([], Name: Moodys_NumericRating, dtype: ...
# 19  Series([], Name: Moodys_NumericRating, dtype: ...
# 20  Series([], Name: Moodys_NumericRating, dtype: ...
# 21  Series([], Name: Moodys_NumericRating, dtype: ...
# 22  Series([], Name: Moodys_NumericRating, dtype: ...
# 23  Series([], Name: Moodys_NumericRating, dtype: ...
# 24  Series([], Name: Moodys_NumericRating, dtype: ...
# 25  Series([], Name: Moodys_NumericRating, dtype: ...
# 26  Series([], Name: Moodys_NumericRating, dtype: ...
# 27  Series([], Name: Moodys_NumericRating, dtype: ...
# 28  Series([], Name: Moodys_NumericRating, dtype: ...
# 29  Series([], Name: Moodys_NumericRating, dtype: ...
# 30  Series([], Name: Moodys_NumericRating, dtype: ...
# ..                                                ...
# 39  Series([], Name: Moodys_NumericRating, dtype: ...
# 40  Series([], Name: Moodys_NumericRating, dtype: ...
# 41  Series([], Name: Moodys_NumericRating, dtype: ...
# 42  Series([], Name: Moodys_NumericRating, dtype: ...
# 43  Series([], Name: Moodys_NumericRating, dtype: ...
# 44  Series([], Name: Moodys_NumericRating, dtype: ...
# 45  Series([], Name: Moodys_NumericRating, dtype: ...
# 46  Series([], Name: Moodys_NumericRating, dtype: ...
# 47  Series([], Name: Moodys_NumericRating, dtype: ...
# 48  Series([], Name: Moodys_NumericRating, dtype: ...
# 49  Series([], Name: Moodys_NumericRating, dtype: ...
# 50  Series([], Name: Moodys_NumericRating, dtype: ...
# 51  Series([], Name: Moodys_NumericRating, dtype: ...
# 52  Series([], Name: Moodys_NumericRating, dtype: ...
# 53  Series([], Name: Moodys_NumericRating, dtype: ...
# 54  Series([], Name: Moodys_NumericRating, dtype: ...
# 55  Series([], Name: Moodys_NumericRating, dtype: ...
# 56  Series([], Name: Moodys_NumericRating, dtype: ...
# 57  Series([], Name: Moodys_NumericRating, dtype: ...
# 58  Series([], Name: Moodys_NumericRating, dtype: ...
# 59  Series([], Name: Moodys_NumericRating, dtype: ...
# 60  Series([], Name: Moodys_NumericRating, dtype: ...
# 61  Series([], Name: Moodys_NumericRating, dtype: ...
# 62  Series([], Name: Moodys_NumericRating, dtype: ...
# 63  Series([], Name: Moodys_NumericRating, dtype: ...
# 64  Series([], Name: Moodys_NumericRating, dtype: ...
# 65  Series([], Name: Moodys_NumericRating, dtype: ...
# 66  Series([], Name: Moodys_NumericRating, dtype: ...
# 67  Series([], Name: Moodys_NumericRating, dtype: ...
# 68  Series([], Name: Moodys_NumericRating, dtype: ...
#
#                          Fitch Sovereign Ratings List
# 1   Series([], Name: Fitch_NumericRating, dtype: f...
# 2   Series([], Name: Fitch_NumericRating, dtype: f...
# 3   Series([], Name: Fitch_NumericRating, dtype: f...
# 4   Series([], Name: Fitch_NumericRating, dtype: f...
# 5   Series([], Name: Fitch_NumericRating, dtype: f...
# 6   Series([], Name: Fitch_NumericRating, dtype: f...
# 7   Series([], Name: Fitch_NumericRating, dtype: f...
# 8   Series([], Name: Fitch_NumericRating, dtype: f...
# 9   Series([], Name: Fitch_NumericRating, dtype: f...
# 10  Series([], Name: Fitch_NumericRating, dtype: f...
# 11  Series([], Name: Fitch_NumericRating, dtype: f...
# 12  Series([], Name: Fitch_NumericRating, dtype: f...
# 13  Series([], Name: Fitch_NumericRating, dtype: f...
# 14  Series([], Name: Fitch_NumericRating, dtype: f...
# 15  Series([], Name: Fitch_NumericRating, dtype: f...
# 16  Series([], Name: Fitch_NumericRating, dtype: f...
# 17  Series([], Name: Fitch_NumericRating, dtype: f...
# 18  Series([], Name: Fitch_NumericRating, dtype: f...
# 19  Series([], Name: Fitch_NumericRating, dtype: f...
# 20  Series([], Name: Fitch_NumericRating, dtype: f...
# 21  Series([], Name: Fitch_NumericRating, dtype: f...
# 22  Series([], Name: Fitch_NumericRating, dtype: f...
# 23  Series([], Name: Fitch_NumericRating, dtype: f...
# 24  Series([], Name: Fitch_NumericRating, dtype: f...
# 25  Series([], Name: Fitch_NumericRating, dtype: f...
# 26  Series([], Name: Fitch_NumericRating, dtype: f...
# 27  Series([], Name: Fitch_NumericRating, dtype: f...
# 28  Series([], Name: Fitch_NumericRating, dtype: f...
# 29  Series([], Name: Fitch_NumericRating, dtype: f...
# 30  Series([], Name: Fitch_NumericRating, dtype: f...
# ..                                                ...
# 39  Series([], Name: Fitch_NumericRating, dtype: f...
# 40  Series([], Name: Fitch_NumericRating, dtype: f...
# 41  Series([], Name: Fitch_NumericRating, dtype: f...
# 42  Series([], Name: Fitch_NumericRating, dtype: f...
# 43  Series([], Name: Fitch_NumericRating, dtype: f...
# 44  Series([], Name: Fitch_NumericRating, dtype: f...
# 45  Series([], Name: Fitch_NumericRating, dtype: f...
# 46  Series([], Name: Fitch_NumericRating, dtype: f...
# 47  Series([], Name: Fitch_NumericRating, dtype: f...
# 48  Series([], Name: Fitch_NumericRating, dtype: f...
# 49  Series([], Name: Fitch_NumericRating, dtype: f...
# 50  Series([], Name: Fitch_NumericRating, dtype: f...
# 51  Series([], Name: Fitch_NumericRating, dtype: f...
# 52  Series([], Name: Fitch_NumericRating, dtype: f...
# 53  Series([], Name: Fitch_NumericRating, dtype: f...
# 54  Series([], Name: Fitch_NumericRating, dtype: f...
# 55  Series([], Name: Fitch_NumericRating, dtype: f...
# 56  Series([], Name: Fitch_NumericRating, dtype: f...
# 57  Series([], Name: Fitch_NumericRating, dtype: f...
# 58  Series([], Name: Fitch_NumericRating, dtype: f...
# 59  Series([], Name: Fitch_NumericRating, dtype: f...
# 60  Series([], Name: Fitch_NumericRating, dtype: f...
# 61  Series([], Name: Fitch_NumericRating, dtype: f...
# 62  Series([], Name: Fitch_NumericRating, dtype: f...
# 63  Series([], Name: Fitch_NumericRating, dtype: f...
# 64  Series([], Name: Fitch_NumericRating, dtype: f...
# 65  Series([], Name: Fitch_NumericRating, dtype: f...
# 66  Series([], Name: Fitch_NumericRating, dtype: f...
# 67  Series([], Name: Fitch_NumericRating, dtype: f...
# 68  Series([], Name: Fitch_NumericRating, dtype: f...
#
# [68 rows x 3 columns]
